# %% [markdown]
# <a href="https://colab.research.google.com/github/EjenY-Poltavchiny/Multithreaded-programming-practice/blob/main/Multithreaded-programming-practice/One-dimensional%20homogeneous%20heat%20equation/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.array([[1, 1], [2, 1.18629], [3, 1.80752], [4, 1.95955], [5, 0.966799], [6, 0.981736], [7, 0.723224], [8, 1.97095]])
x = data1[:,0]
y = data1[:,1]

plt.figure(figsize = (12,7))
plt.plot(x, y, label="N = 2000")

data2 = np.array([[1, 1], [2, 1.63855], [3, 2.4927], [4, 3.45026], [5, 2.20735], [6, 3.96083], [7, 1.80932], [8, 4.3617]])
x = data2[:,0]
y = data2[:,1]

plt.plot(x, y, label="N = 10000")

data3 = np.array([[1, 1], [2, 1.8331], [3, 2.5515], [4, 3.17651], [5, 3.28261], [6, 4.58623], [7, 4.19657], [8, 4.07129] ])
x = data3[:,0]
y = data3[:,1]

plt.plot(x, y, label="N = 50000")
plt.legend()
plt.xlabel("number of processes")
plt.ylabel("Boost")
plt.show()
