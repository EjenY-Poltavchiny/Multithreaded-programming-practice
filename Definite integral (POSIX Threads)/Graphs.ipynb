# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.array([[1, 1], [2, 2.33], [3, 3.26], [4, 3.93], [5, 4.2], [6, 4.19], [7, 4.27], [8, 4.18]])
x = data1[:,0]
y = data1[:,1]

plt.figure(figsize = (12,7))
plt.title("S(p) for N = 10^8")
plt.plot(x, y)
