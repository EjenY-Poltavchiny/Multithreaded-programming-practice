# %% [markdown]
# <a href="https://colab.research.google.com/github/EjenY-Poltavchiny/Multithreaded-programming-practice/blob/main/Definite%20integral/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.array([[1, 1], [2, 0.00103379], [3, 0.00447074], [4, 0.000424954], [5, 0.0134849], [6, 0.00529723], [7, 0.00583425], [8, 0.00465384]])
x = data1[:,0]
y = data1[:,1]

plt.figure(figsize = (12,7))
plt.plot(x, y, label="N = 1000")

data2 = np.array([[1, 1], [2, 1.1002], [3, 1.19183], [4, 1.79787], [5, 3.33931], [6, 3.68595], [7, 4.60522], [8, 4.08454]])
x = data2[:,0]
y = data2[:,1]

plt.plot(x, y, label="N = 1000000")

data3 = np.array([[1, 1], [2, 0.865779], [3, 3.00503], [4, 1.60138], [5, 2.70813], [6, 2.92784], [7, 3.49725], [8, 6.56211]])
x = data3[:,0]
y = data3[:,1]

plt.plot(x, y, label="N = 100000000")
plt.legend()
plt.xlabel("number of processes")
plt.ylabel("Boost")
plt.show()
